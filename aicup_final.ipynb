# %% [markdown]
# # 資料前處理

# %%
import os
import pandas as pd
from google.colab import drive

drive.mount('/content/drive')

base_path = '/content/drive/MyDrive/data'
add_path = '/content/drive/MyDrive/addit'

full_data = pd.DataFrame()

# 將17個地點的dataset合併起來
for i in range(1, 18):
    folder_name = f'l{i:02d}'
    folder_path = os.path.join(base_path, folder_name)

    train_file = os.path.join(folder_path, f'train_{i:02d}.csv')
    incomplete_file = os.path.join(folder_path, f'incom_{i:02d}.csv')
    test_file = os.path.join(folder_path, f'test_{i:02d}.csv')

    train_data = pd.read_csv(train_file, header=None, encoding='utf-8')
    train_data.columns = ['Time', 'WindSpeed(m/s)', 'Pressure(hpa)', 'Temperature(°C)', 'Humidity(%)', 'Sunlight(Lux)', 'Target']

    incomplete_data = pd.read_csv(incomplete_file, header=None, encoding='utf-8')
    incomplete_data.columns = ['Time', 'WindSpeed(m/s)', 'Pressure(hpa)', 'Temperature(°C)', 'Humidity(%)', 'Sunlight(Lux)', 'Target']

    test_data = pd.read_csv(test_file, header=None, encoding='utf-8')
    test_data.columns = ['Time', 'WindSpeed(m/s)', 'Pressure(hpa)', 'Temperature(°C)', 'Humidity(%)', 'Sunlight(Lux)', 'Target']

    merged_data = pd.concat([train_data, incomplete_data, test_data], ignore_index=True)

    # 分開時間與地點
    merged_data['Time'] = merged_data['Time'].astype(str)
    merged_data['ds'] = pd.to_datetime(merged_data['Time'].str[:-2], format='%Y%m%d%H%M')
    merged_data['Location'] = merged_data['Time'].str[-2:]

    full_data = pd.concat([full_data, merged_data], ignore_index=True)

# additional data
for n in range(1, 15):
    add_file = os.path.join(add_path, f'{n:d}.csv')
    add_data = pd.read_csv(add_file, header=None, encoding='utf-8')
    add_data.columns = ['Time', 'WindSpeed(m/s)', 'Pressure(hpa)', 'Temperature(°C)', 'Humidity(%)', 'Sunlight(Lux)', 'Target']

    add_data['Time'] = add_data['Time'].astype(str)
    add_data['ds'] = pd.to_datetime(add_data['Time'].str[:-2], format='%Y%m%d%H%M')
    add_data['Location'] = add_data['Time'].str[-2:]

    full_data = pd.concat([full_data, add_data], ignore_index=True)

# 按時間排序
full_data = full_data.sort_values(by='ds').reset_index(drop=True)

# 將ds欄位拆分成各種時間特徵
full_data['month'] = full_data['ds'].dt.month
full_data['weekday'] = full_data['ds'].dt.weekday
full_data['day'] = full_data['ds'].dt.day
full_data['hour'] = full_data['ds'].dt.hour
full_data['minute'] = full_data['ds'].dt.minute

# 新增季節欄位，根據月份來分配季節
def assign_season(month):
    if month in [12, 1, 2]:
        return 1  # 冬季
    elif month in [3, 4, 5]:
        return 3  # 春季
    elif month in [6, 7, 8]:
        return 4  # 夏季
    else:
        return 2  # 秋季

full_data['season'] = full_data['month'].apply(assign_season)

# 模型需要數值型資料
full_data['ds_numeric'] = (full_data['ds'] - pd.to_datetime('1970-01-01')).dt.total_seconds()
full_data['Location'] = full_data['Location'].astype(int)
# 確認結果
print(f"資料合併完成，共 {len(full_data)} 筆資料。")

# 儲存合併後的資料
output_file = '/content/full_train_data.csv'
full_data.to_csv(output_file, index=False)
print(f"合併後的資料已儲存至 {output_file}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 資料合併完成，共 103878 筆資料。
# 合併後的資料已儲存至 /content/full_train_data.csv

# %% [markdown]
# #最終測試集

# %%
import pandas as pd
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
import os
import pickle
import numpy as np

# 讀取訓練資料
train_data = pd.read_csv('/content/full_train_data.csv')

# 設定目標變數和特徵
env_columns = ['Temperature(°C)', 'Humidity(%)', 'Sunlight(Lux)', 'Location']
time_columns = ['month', 'hour', 'season', 'weekday', 'day', 'minute', 'ds_numeric']
features_2 = env_columns + time_columns

# 用時間跟地點預測三個特徵：溫度、濕度和光照
def f1(feature_name):
    print(f"正在訓練 {feature_name} 預測模型...")

    features = time_columns + ['Location']
    X = train_data[features]
    y = train_data[feature_name]

    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.05, random_state=42)

    # XGBoost
    model = XGBRegressor(
        n_estimators=5000,
        learning_rate=0.05,
        max_depth=10,
        random_state=42,
        early_stopping_rounds=50
    )

    model.fit(
        X_train, y_train,
        eval_set=[(X_val, y_val)],
        verbose=False
    )

    y_pred_val = model.predict(X_val)
    diff_sum = np.sum(np.abs(y_val - y_pred_val))
    print(f"Valid絕對誤差總和: {diff_sum}")

    return model

# 用預測後的數值 去掉自身欄位 再做預測
def f2(feature_name):
    print(f"正在訓練 {feature_name} 預測模型...")

    features = features_2
    X = train_data[features].drop(columns=[feature_name])
    y = train_data[feature_name]

    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.05, random_state=42)

    # XGBoost
    model = XGBRegressor(
        n_estimators=5000,
        learning_rate=0.05,
        max_depth=10,
        random_state=42,
        early_stopping_rounds=50
    )

    model.fit(
        X_train, y_train,
        eval_set=[(X_val, y_val)],
        verbose=False
    )

    y_pred_val = model.predict(X_val)
    diff_sum = np.sum(np.abs(y_val - y_pred_val))
    print(f"Valid絕對誤差總和: {diff_sum}")

    return model

# 保存模型
def save_model(model, model_name):
    with open(f"{model_name}.pkl", "wb") as file:
        pickle.dump(model, file)
    print(f"{model_name} 已保存到 {model_name}.pkl")

# 載入模型
def load_model(model_name):
    with open(f"{model_name}.pkl", "rb") as file:
        return pickle.load(file)

temperature_model = f1('Temperature(°C)')
humidity_model = f1('Humidity(%)')
sunlight_model = f1('Sunlight(Lux)')

temperature_model_v2 = f2('Temperature(°C)')
humidity_model_v2 = f2('Humidity(%)')
sunlight_model_v2 = f2('Sunlight(Lux)')

# 保存模型
save_model(temperature_model, "temperature_model")
save_model(humidity_model, "humidity_model")
save_model(sunlight_model, "sunlight_model")
save_model(temperature_model_v2, "temperature_model_v2")
save_model(humidity_model_v2, "humidity_model_v2")
save_model(sunlight_model_v2, "sunlight_model_v2")

# 載入模型
temperature_model = load_model("temperature_model")
humidity_model = load_model("humidity_model")
sunlight_model = load_model("sunlight_model")
temperature_model_v2 = load_model("temperature_model_v2")
humidity_model_v2 = load_model("humidity_model_v2")
sunlight_model_v2 = load_model("sunlight_model_v2")

# 加上預測後的特徵數值
# data 資料 model 模型2 target w1 原特徵權重 w2 再預測模型2權重
def update(data, model, target, w1, w2):
    data[target] = (data[target] * w1 + w2 * model.predict(data[features_2].drop(columns=[target]))).clip(lower=0)

    return data[target]

def pred_test(test_data, temperature_model, humidity_model, sunlight_model):

    # 使用時間特徵模型來預測test的溫度、濕度和光照
    test_data['Temperature(°C)'] = temperature_model.predict(test_data[time_columns + ['Location']])
    test_data['Humidity(%)'] = humidity_model.predict(test_data[time_columns + ['Location']])
    test_data['Sunlight(Lux)'] = sunlight_model.predict(test_data[time_columns + ['Location']])

    return test_data


test_file = os.path.join(os.getcwd(), 'testset.csv')
test_data = pd.read_csv(test_file, header=None, encoding='utf-8')
test_data.columns = ['Time', 'Answer']

#對test做預處理
test_data['Time'] = test_data['Time'].astype(str)
test_data['ds'] = pd.to_datetime(test_data['Time'].str[:-2], format='%Y%m%d%H%M')
test_data['Location'] = test_data['Time'].str[-2:]

test_data['month'] = test_data['ds'].dt.month
test_data['weekday'] = test_data['ds'].dt.weekday
test_data['day'] = test_data['ds'].dt.day
test_data['hour'] = test_data['ds'].dt.hour
test_data['minute'] = test_data['ds'].dt.minute
test_data['season'] = test_data['month'].apply(assign_season)

test_data['ds_numeric'] = (test_data['ds'] - pd.to_datetime('1970-01-01')).dt.total_seconds()
test_data['Location'] = test_data['Location'].astype(int)

test_data = pred_test(test_data, temperature_model, humidity_model, sunlight_model)

w1 = 0.9
w2 = 0.1
y1 = 0.95
y2 = 0.05
# 重複預測 並配比權重來降低誤差
for i in range(2):
  test_data['Temperature(°C)'] = update(test_data, temperature_model_v2, 'Temperature(°C)', w1, w2)
  test_data['Humidity(%)'] = update(test_data, humidity_model_v2, 'Humidity(%)', w1, w2)
  test_data['Sunlight(Lux)'] = update(test_data, sunlight_model_v2, 'Sunlight(Lux)', w1, w2)
test_data['Humidity(%)'] = update(test_data, humidity_model_v2, 'Humidity(%)', y1, y2)
test_data['Sunlight(Lux)'] = update(test_data, sunlight_model_v2, 'Sunlight(Lux)', y1, y2)
test_data['Humidity(%)'] = update(test_data, humidity_model_v2, 'Humidity(%)', y1, y2)
test_data['Humidity(%)'] = update(test_data, humidity_model_v2, 'Humidity(%)', y1, y2)
test_data['Humidity(%)'] = update(test_data, humidity_model_v2, 'Humidity(%)', y1, y2)

# 儲存預測結果
test_data.to_csv('xgbBoost_test_final.csv', index=False)
print("預測結果已儲存在 xgbBoost_test_final.csv 中")
# Out:
# 正在訓練 Temperature(°C) 預測模型...
# Valid絕對誤差總和: 2947.030661849976
# 正在訓練 Humidity(%) 預測模型...
# Valid絕對誤差總和: 8401.283160438536
# 正在訓練 Sunlight(Lux) 預測模型...
# Valid絕對誤差總和: 16921132.96212837
# 正在訓練 Temperature(°C) 預測模型...
# Valid絕對誤差總和: 1813.66791015625
# 正在訓練 Humidity(%) 預測模型...
# Valid絕對誤差總和: 5786.562985801696
# 正在訓練 Sunlight(Lux) 預測模型...
# Valid絕對誤差總和: 19191885.902021028
# temperature_model 已保存到 temperature_model.pkl
# humidity_model 已保存到 humidity_model.pkl
# sunlight_model 已保存到 sunlight_model.pkl
# temperature_model_v2 已保存到 temperature_model_v2.pkl
# humidity_model_v2 已保存到 humidity_model_v2.pkl
# sunlight_model_v2 已保存到 sunlight_model_v2.pkl
# 預測結果已儲存在 xgbBoost_test_final.csv 中

# %% [markdown]
# #最終模型

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from xgboost import XGBRegressor
import os
import numpy as np

# 讀取訓練資料
train_data = pd.read_csv('/content/full_train_data.csv')

# 環境特徵與時間特徵
env_columns = ['Temperature(°C)', 'Sunlight(Lux)', 'Humidity(%)', 'Location']
time_columns = ['month', 'hour', 'weekday', 'minute', 'ds_numeric']

# 最終採用之特徵
features = env_columns + time_columns

# 切割訓練集和驗證集
X = train_data[features]
y = train_data['Target']
# 驗證集約會有5000筆資料
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.05, random_state=42)

# XGBoost
xgb_model = XGBRegressor(
    subsample=0.7,
    n_estimators=5000,
    max_depth=10,
    learning_rate=0.05,
    random_state=42,
    early_stopping_rounds=50,
    eval_metric="mae"
)

xgb_model.fit(
    X_train, y_train,
    eval_set=[(X_val, y_val)],
    verbose=True
)

save_model(xgb_model, "xgb_model")

# xgb_model = load_model("xgb_model")

# 驗證集的絕對誤差總和
y_pred_val = xgb_model.predict(X_val)
diff_sum = np.sum(np.abs(y_val - y_pred_val))
print(f"Valid絕對誤差總和: {diff_sum}")

# test
test_file = os.path.join(os.getcwd(), 'xgbBoost_test_final.csv')
test_data = pd.read_csv(test_file,encoding='utf-8')

# 預測test發電量
test_data['Answer'] = xgb_model.predict(test_data[features])

# 輸出結果
output = pd.DataFrame()
output['Time'] = test_data['Time'].astype(int)
output['Pred'] = test_data['Answer']
output['Pred'] = output['Pred'].clip(lower=0)

output.to_csv('XGBoost_Predictions_xgb.csv', index=False)
print("XGBoost 預測結果已儲存至 XGBoost_Predictions_xgb.csv")
# Out:
# [0]	validation_0-mae:371.90576
# [1]	validation_0-mae:353.86666
# [2]	validation_0-mae:336.77579
# [3]	validation_0-mae:320.62305
# [4]	validation_0-mae:305.31607
# [5]	validation_0-mae:290.72429
# [6]	validation_0-mae:276.96235
# [7]	validation_0-mae:263.85159
# [8]	validation_0-mae:251.42228
# [9]	validation_0-mae:239.63793
# [10]	validation_0-mae:228.47224
# [11]	validation_0-mae:217.86294
# [12]	validation_0-mae:207.81369
# [13]	validation_0-mae:198.24376
# [14]	validation_0-mae:189.20933
# [15]	validation_0-mae:180.56955
# [16]	validation_0-mae:172.38909
# [17]	validation_0-mae:164.62825
# [18]	validation_0-mae:157.32419
# [19]	validation_0-mae:150.40468
# [20]	validation_0-mae:143.84394
# [21]	validation_0-mae:137.55461
# [22]	validation_0-mae:131.62177
# [23]	validation_0-mae:126.01791
# [24]	validation_0-mae:120.68993
# [25]	validation_0-mae:115.57460
# [26]	validation_0-mae:110.78743
# [27]	validation_0-mae:106.28017
# [28]	validation_0-mae:101.91653
# [29]	validation_0-mae:97.86038
# [30]	validation_0-mae:94.00475
# [31]	validation_0-mae:90.36319
# [32]	validation_0-mae:86.96504
# [33]	validation_0-mae:83.69601
# [34]	validation_0-mae:80.54818
# [35]	validation_0-mae:77.60880
# [36]	validation_0-mae:74.83090
# [37]	validation_0-mae:72.20893
# [38]	validation_0-mae:69.75116
# [39]	validation_0-mae:67.37338
# [40]	validation_0-mae:65.12039
# [41]	validation_0-mae:63.04190
# [42]	validation_0-mae:61.10089
# [43]	validation_0-mae:59.18704
# [44]	validation_0-mae:57.38543
# [45]	validation_0-mae:55.75005
# [46]	validation_0-mae:54.13952
# [47]	validation_0-mae:52.65683
# [48]	validation_0-mae:51.21686
# [49]	validation_0-mae:49.89725
# [50]	validation_0-mae:48.62210
# [51]	validation_0-mae:47.39430
# [52]	validation_0-mae:46.21069
# [53]	validation_0-mae:45.13229
# [54]	validation_0-mae:44.12535
# [55]	validation_0-mae:43.15041
# [56]	validation_0-mae:42.23952
# [57]	validation_0-mae:41.35565
# [58]	validation_0-mae:40.51192
# [59]	validation_0-mae:39.74798
# [60]	validation_0-mae:38.96307
# [61]	validation_0-mae:38.26424
# [62]	validation_0-mae:37.55044
# [63]	validation_0-mae:36.86047
# [64]	validation_0-mae:36.29728
# [65]	validation_0-mae:35.72199
# [66]	validation_0-mae:35.17027
# [67]	validation_0-mae:34.59508
# [68]	validation_0-mae:34.09181
# [69]	validation_0-mae:33.59270
# [70]	validation_0-mae:33.17185
# [71]	validation_0-mae:32.73760
# [72]	validation_0-mae:32.32816
# [73]	validation_0-mae:31.91116
# [74]	validation_0-mae:31.46753
# [75]	validation_0-mae:31.10008
# [76]	validation_0-mae:30.75588
# [77]	validation_0-mae:30.42420
# [78]	validation_0-mae:30.09327
# [79]	validation_0-mae:29.78172
# [80]	validation_0-mae:29.49314
# [81]	validation_0-mae:29.26867
# [82]	validation_0-mae:28.99124
# [83]	validation_0-mae:28.74880
# [84]	validation_0-mae:28.51161
# [85]	validation_0-mae:28.27013
# [86]	validation_0-mae:28.03175
# [87]	validation_0-mae:27.82935
# [88]	validation_0-mae:27.61681
# [89]	validation_0-mae:27.46794
# [90]	validation_0-mae:27.30625
# [91]	validation_0-mae:27.11542
# [92]	validation_0-mae:26.93877
# [93]	validation_0-mae:26.79470
# [94]	validation_0-mae:26.66988
# [95]	validation_0-mae:26.53254
# [96]	validation_0-mae:26.37906
# [97]	validation_0-mae:26.25131
# [98]	validation_0-mae:26.10496
# [99]	validation_0-mae:26.00345
# [100]	validation_0-mae:25.86740
# [101]	validation_0-mae:25.73521
# [102]	validation_0-mae:25.61802
# [103]	validation_0-mae:25.48860
# [104]	validation_0-mae:25.37729
# [105]	validation_0-mae:25.30574
# [106]	validation_0-mae:25.23309
# [107]	validation_0-mae:25.14443
# [108]	validation_0-mae:25.09304
# [109]	validation_0-mae:25.00107
# [110]	validation_0-mae:24.94122
# [111]	validation_0-mae:24.88200
# [112]	validation_0-mae:24.78940
# [113]	validation_0-mae:24.72470
# [114]	validation_0-mae:24.62865
# [115]	validation_0-mae:24.57267
# [116]	validation_0-mae:24.49053
# [117]	validation_0-mae:24.43057
# [118]	validation_0-mae:24.35894
# [119]	validation_0-mae:24.31107
# [120]	validation_0-mae:24.24687
# [121]	validation_0-mae:24.20192
# [122]	validation_0-mae:24.12844
# [123]	validation_0-mae:24.09055
# [124]	validation_0-mae:24.04355
# [125]	validation_0-mae:23.97586
# [126]	validation_0-mae:23.93113
# [127]	validation_0-mae:23.87168
# [128]	validation_0-mae:23.81616
# [129]	validation_0-mae:23.77742
# [130]	validation_0-mae:23.74324
# [131]	validation_0-mae:23.71385
# [132]	validation_0-mae:23.68198
# [133]	validation_0-mae:23.61324
# [134]	validation_0-mae:23.59726
# [135]	validation_0-mae:23.56270
# [136]	validation_0-mae:23.53000
# [137]	validation_0-mae:23.48303
# [138]	validation_0-mae:23.43448
# [139]	validation_0-mae:23.41776
# [140]	validation_0-mae:23.38217
# [141]	validation_0-mae:23.36609
# [142]	validation_0-mae:23.32125
# [143]	validation_0-mae:23.29040
# [144]	validation_0-mae:23.24519
# [145]	validation_0-mae:23.21114
# [146]	validation_0-mae:23.18771
# [489]	validation_0-mae:20.51982
# [490]	validation_0-mae:20.52061
# [491]	validation_0-mae:20.52100
# [492]	validation_0-mae:20.51642
# [493]	validation_0-mae:20.51650
# [494]	validation_0-mae:20.51132
# [495]	validation_0-mae:20.50876
# [496]	validation_0-mae:20.50008
# [497]	validation_0-mae:20.49556
# [498]	validation_0-mae:20.49472
# [499]	validation_0-mae:20.49505
# [500]	validation_0-mae:20.49179
# [501]	validation_0-mae:20.49221
# [502]	validation_0-mae:20.49362
# [503]	validation_0-mae:20.49035
# [504]	validation_0-mae:20.48599
# [505]	validation_0-mae:20.48529
# [506]	validation_0-mae:20.47917
# [507]	validation_0-mae:20.47545
# [508]	validation_0-mae:20.48042
# [509]	validation_0-mae:20.47564
# [510]	validation_0-mae:20.47271
# [511]	validation_0-mae:20.46751
# [512]	validation_0-mae:20.46499
# [513]	validation_0-mae:20.46372
# [514]	validation_0-mae:20.46365
# [515]	validation_0-mae:20.46709
# [516]	validation_0-mae:20.46264
# [517]	validation_0-mae:20.46088
# [518]	validation_0-mae:20.46262
# [519]	validation_0-mae:20.45962
# [520]	validation_0-mae:20.46091
# [521]	validation_0-mae:20.46089
# [522]	validation_0-mae:20.46155
# [523]	validation_0-mae:20.45847
# [524]	validation_0-mae:20.45629
# [525]	validation_0-mae:20.45255
# [526]	validation_0-mae:20.45715
# [527]	validation_0-mae:20.45864
# [528]	validation_0-mae:20.45747
# [529]	validation_0-mae:20.45423
# [530]	validation_0-mae:20.45385
# [531]	validation_0-mae:20.45103
# [532]	validation_0-mae:20.44906
# [533]	validation_0-mae:20.44321
# [534]	validation_0-mae:20.44015
# [535]	validation_0-mae:20.43647
# [536]	validation_0-mae:20.43752
# [537]	validation_0-mae:20.43865
# [538]	validation_0-mae:20.43543
# [539]	validation_0-mae:20.43197
# [540]	validation_0-mae:20.43337
# [541]	validation_0-mae:20.42889
# [542]	validation_0-mae:20.43157
# [543]	validation_0-mae:20.43067
# [544]	validation_0-mae:20.42686
# [545]	validation_0-mae:20.42571
# [546]	validation_0-mae:20.42151
# [547]	validation_0-mae:20.42176
# [548]	validation_0-mae:20.42071
# [549]	validation_0-mae:20.41423
# [550]	validation_0-mae:20.41350
# [551]	validation_0-mae:20.40726
# [552]	validation_0-mae:20.40969
# [553]	validation_0-mae:20.40843
# [554]	validation_0-mae:20.40213
# [555]	validation_0-mae:20.39871
# [556]	validation_0-mae:20.39680
# [557]	validation_0-mae:20.39526
# [558]	validation_0-mae:20.39009
# [559]	validation_0-mae:20.38976
# [560]	validation_0-mae:20.38348
# [561]	validation_0-mae:20.37591
# [562]	validation_0-mae:20.37420
# [563]	validation_0-mae:20.36884
# [564]	validation_0-mae:20.36233
# [565]	validation_0-mae:20.36240
# [566]	validation_0-mae:20.36391
# [567]	validation_0-mae:20.36946
# [568]	validation_0-mae:20.36684
# [569]	validation_0-mae:20.36423
# [570]	validation_0-mae:20.36285
# [571]	validation_0-mae:20.36311
# [572]	validation_0-mae:20.36475
# [573]	validation_0-mae:20.35774
# [574]	validation_0-mae:20.35850
# [575]	validation_0-mae:20.35493
# [576]	validation_0-mae:20.35207
# [577]	validation_0-mae:20.35117
# [578]	validation_0-mae:20.34749
# [579]	validation_0-mae:20.34714
# [580]	validation_0-mae:20.34366
# [581]	validation_0-mae:20.33764
# [582]	validation_0-mae:20.33500
# [583]	validation_0-mae:20.33106
# [584]	validation_0-mae:20.32773
# [585]	validation_0-mae:20.32633
# [586]	validation_0-mae:20.32275
# [587]	validation_0-mae:20.31813
# [588]	validation_0-mae:20.31425
# [589]	validation_0-mae:20.31195
# [590]	validation_0-mae:20.31572
# [591]	validation_0-mae:20.31546
# [592]	validation_0-mae:20.31377
# [593]	validation_0-mae:20.31022
# [594]	validation_0-mae:20.30475
# [595]	validation_0-mae:20.30215
# [596]	validation_0-mae:20.29688
# [597]	validation_0-mae:20.29642
# [598]	validation_0-mae:20.29260
# [599]	validation_0-mae:20.29115
# [600]	validation_0-mae:20.28963
# [601]	validation_0-mae:20.29364
# [602]	validation_0-mae:20.30119
# [603]	validation_0-mae:20.29866
# [604]	validation_0-mae:20.29948
# [605]	validation_0-mae:20.29930
# [606]	validation_0-mae:20.29445
# [607]	validation_0-mae:20.29509
# [608]	validation_0-mae:20.29493
# [609]	validation_0-mae:20.29245
# [610]	validation_0-mae:20.29198
# [611]	validation_0-mae:20.29072
# [612]	validation_0-mae:20.29119
# [613]	validation_0-mae:20.28892
# [614]	validation_0-mae:20.28449
# [615]	validation_0-mae:20.28185
# [616]	validation_0-mae:20.27861
# [617]	validation_0-mae:20.27416
# [618]	validation_0-mae:20.27652
# [619]	validation_0-mae:20.27321
# [620]	validation_0-mae:20.27272
# [621]	validation_0-mae:20.27238
# [622]	validation_0-mae:20.27096
# [623]	validation_0-mae:20.27213
# [624]	validation_0-mae:20.26930
# [625]	validation_0-mae:20.27030
# [626]	validation_0-mae:20.26610
# [627]	validation_0-mae:20.26527
# [628]	validation_0-mae:20.26457
# [629]	validation_0-mae:20.26239
# [630]	validation_0-mae:20.25801
# [631]	validation_0-mae:20.25507
# [632]	validation_0-mae:20.25548
# [633]	validation_0-mae:20.25546
# [634]	validation_0-mae:20.25412
# [635]	validation_0-mae:20.25106
# [636]	validation_0-mae:20.24732
# [637]	validation_0-mae:20.24881
# [638]	validation_0-mae:20.24843
# [639]	validation_0-mae:20.24351
# [640]	validation_0-mae:20.24350
# [641]	validation_0-mae:20.23935
# [642]	validation_0-mae:20.24261
# [643]	validation_0-mae:20.23671
# [644]	validation_0-mae:20.23748
# [645]	validation_0-mae:20.24027
# [646]	validation_0-mae:20.24215
# [647]	validation_0-mae:20.23802
# [648]	validation_0-mae:20.23846
# [649]	validation_0-mae:20.23678
# [650]	validation_0-mae:20.23740
# [651]	validation_0-mae:20.23314
# [652]	validation_0-mae:20.23378
# [653]	validation_0-mae:20.23337
# [654]	validation_0-mae:20.23393
# [655]	validation_0-mae:20.23624
# [656]	validation_0-mae:20.23790
# [657]	validation_0-mae:20.23725
# [658]	validation_0-mae:20.23850
# [659]	validation_0-mae:20.23967
# [660]	validation_0-mae:20.24674
# [661]	validation_0-mae:20.24590
# [662]	validation_0-mae:20.24742
# [663]	validation_0-mae:20.24691
# [664]	validation_0-mae:20.24532
# [665]	validation_0-mae:20.24509
# [666]	validation_0-mae:20.24500
# [667]	validation_0-mae:20.24721
# [668]	validation_0-mae:20.24829
# [669]	validation_0-mae:20.25095
# [670]	validation_0-mae:20.24976
# [671]	validation_0-mae:20.24729
# [672]	validation_0-mae:20.24491
# [673]	validation_0-mae:20.24708
# [674]	validation_0-mae:20.24726
# [675]	validation_0-mae:20.24604
# [676]	validation_0-mae:20.24290
# [677]	validation_0-mae:20.24078
# [678]	validation_0-mae:20.23890
# [679]	validation_0-mae:20.23776
# [680]	validation_0-mae:20.23701
# [681]	validation_0-mae:20.23880
# [682]	validation_0-mae:20.23390
# [683]	validation_0-mae:20.23256
# [684]	validation_0-mae:20.23640
# [685]	validation_0-mae:20.23694
# [686]	validation_0-mae:20.23494
# [687]	validation_0-mae:20.23365
# [688]	validation_0-mae:20.23398
# [689]	validation_0-mae:20.23008
# [690]	validation_0-mae:20.22596
# [691]	validation_0-mae:20.22379
# [692]	validation_0-mae:20.22286
# [693]	validation_0-mae:20.22212
# [694]	validation_0-mae:20.22040
# [695]	validation_0-mae:20.21741
# [696]	validation_0-mae:20.21651
# [697]	validation_0-mae:20.21477
# [698]	validation_0-mae:20.21556
# [699]	validation_0-mae:20.21606
# [700]	validation_0-mae:20.21393
# [701]	validation_0-mae:20.21439
# [702]	validation_0-mae:20.21473
# [703]	validation_0-mae:20.21025
# [704]	validation_0-mae:20.20956
# [705]	validation_0-mae:20.20989
# [706]	validation_0-mae:20.20904
# [707]	validation_0-mae:20.20763
# [708]	validation_0-mae:20.20614
# [709]	validation_0-mae:20.20666
# [710]	validation_0-mae:20.20891
# [711]	validation_0-mae:20.20658
# [712]	validation_0-mae:20.20648
# [713]	validation_0-mae:20.20526
# [714]	validation_0-mae:20.20606
# [715]	validation_0-mae:20.20699
# [716]	validation_0-mae:20.20494
# [717]	validation_0-mae:20.20559
# [718]	validation_0-mae:20.20317
# [719]	validation_0-mae:20.20173
# [720]	validation_0-mae:20.20180
# [721]	validation_0-mae:20.20222
# [722]	validation_0-mae:20.20473
# [723]	validation_0-mae:20.20295
# [724]	validation_0-mae:20.19915
# [725]	validation_0-mae:20.19691
# [726]	validation_0-mae:20.19798
# [727]	validation_0-mae:20.19691
# [728]	validation_0-mae:20.19441
# [729]	validation_0-mae:20.19406
# [730]	validation_0-mae:20.18983
# [731]	validation_0-mae:20.19293
# [732]	validation_0-mae:20.18909
# [733]	validation_0-mae:20.19046
# [734]	validation_0-mae:20.19388
# [735]	validation_0-mae:20.18977
# [736]	validation_0-mae:20.18904
# [737]	validation_0-mae:20.18484
# [738]	validation_0-mae:20.18394
# [739]	validation_0-mae:20.18270
# [740]	validation_0-mae:20.18432
# [741]	validation_0-mae:20.18473
# [742]	validation_0-mae:20.18452
# [743]	validation_0-mae:20.18119
# [744]	validation_0-mae:20.18080
# [916]	validation_0-mae:20.07056
# [917]	validation_0-mae:20.07168
# [918]	validation_0-mae:20.07445
# [919]	validation_0-mae:20.07477
# [920]	validation_0-mae:20.07491
# [921]	validation_0-mae:20.07394
# [922]	validation_0-mae:20.07290
# [923]	validation_0-mae:20.07127
# [924]	validation_0-mae:20.07028
# [925]	validation_0-mae:20.06894
# [926]	validation_0-mae:20.06785
# [927]	validation_0-mae:20.06537
# [928]	validation_0-mae:20.06438
# [929]	validation_0-mae:20.06328
# [930]	validation_0-mae:20.06333
# [931]	validation_0-mae:20.06291
# [932]	validation_0-mae:20.06174
# [933]	validation_0-mae:20.06133
# [934]	validation_0-mae:20.06262
# [935]	validation_0-mae:20.06113
# [936]	validation_0-mae:20.06207
# [937]	validation_0-mae:20.06247
# [938]	validation_0-mae:20.06103
# [939]	validation_0-mae:20.06108
# [940]	validation_0-mae:20.06067
# [941]	validation_0-mae:20.06060
# [942]	validation_0-mae:20.06112
# [943]	validation_0-mae:20.06101
# [944]	validation_0-mae:20.06033
# [945]	validation_0-mae:20.06035
# [946]	validation_0-mae:20.05899
# [947]	validation_0-mae:20.05927
# [948]	validation_0-mae:20.06105
# [949]	validation_0-mae:20.05851
# [950]	validation_0-mae:20.05659
# [951]	validation_0-mae:20.05752
# [952]	validation_0-mae:20.05805
# [953]	validation_0-mae:20.05534
# [954]	validation_0-mae:20.05386
# [955]	validation_0-mae:20.05259
# [956]	validation_0-mae:20.04917
# [957]	validation_0-mae:20.05015
# [958]	validation_0-mae:20.04946
# [959]	validation_0-mae:20.04766
# [960]	validation_0-mae:20.04711
# [961]	validation_0-mae:20.04577
# [962]	validation_0-mae:20.04771
# [963]	validation_0-mae:20.04827
# [964]	validation_0-mae:20.04720
# [965]	validation_0-mae:20.04555
# [966]	validation_0-mae:20.04446
# [967]	validation_0-mae:20.04413
# [968]	validation_0-mae:20.04272
# [969]	validation_0-mae:20.04286
# [970]	validation_0-mae:20.04200
# [971]	validation_0-mae:20.04333
# [972]	validation_0-mae:20.04142
# [973]	validation_0-mae:20.04183
# [974]	validation_0-mae:20.04026
# [975]	validation_0-mae:20.03960
# [976]	validation_0-mae:20.03899
# [977]	validation_0-mae:20.03920
# [978]	validation_0-mae:20.03893
# [979]	validation_0-mae:20.03768
# [980]	validation_0-mae:20.03624
# [981]	validation_0-mae:20.03680
# [982]	validation_0-mae:20.03539
# [983]	validation_0-mae:20.03389
# [984]	validation_0-mae:20.03344
# [985]	validation_0-mae:20.03403
# [986]	validation_0-mae:20.03375
# [987]	validation_0-mae:20.03184
# [988]	validation_0-mae:20.03131
# [989]	validation_0-mae:20.03206
# [990]	validation_0-mae:20.03096
# [991]	validation_0-mae:20.03226
# [992]	validation_0-mae:20.03275
# [993]	validation_0-mae:20.03284
# [994]	validation_0-mae:20.03311
# [995]	validation_0-mae:20.03173
# [996]	validation_0-mae:20.03221
# [997]	validation_0-mae:20.03130
# [998]	validation_0-mae:20.03259
# [999]	validation_0-mae:20.03079
# [1000]	validation_0-mae:20.03010
# [1082]	validation_0-mae:19.98714
# [1083]	validation_0-mae:19.98660
# [1084]	validation_0-mae:19.98612
# [1085]	validation_0-mae:19.98419
# [1086]	validation_0-mae:19.98497
# [1087]	validation_0-mae:19.98411
# [1088]	validation_0-mae:19.98436
# [1089]	validation_0-mae:19.98347
# [1090]	validation_0-mae:19.98480
# [1091]	validation_0-mae:19.98479
# [1092]	validation_0-mae:19.98409
# [1093]	validation_0-mae:19.98299
# [1094]	validation_0-mae:19.98201
# [1095]	validation_0-mae:19.98186
# [1096]	validation_0-mae:19.98162
# [1097]	validation_0-mae:19.98132
# [1098]	validation_0-mae:19.98065
# [1099]	validation_0-mae:19.98069
# [1100]	validation_0-mae:19.97969
# [1101]	validation_0-mae:19.97953
# [1102]	validation_0-mae:19.97708
# [1103]	validation_0-mae:19.97674
# [1104]	validation_0-mae:19.97645
# [1105]	validation_0-mae:19.97751
# [1106]	validation_0-mae:19.97509
# [1107]	validation_0-mae:19.97395
# [1108]	validation_0-mae:19.97297
# [1109]	validation_0-mae:19.97195
# [1110]	validation_0-mae:19.97111
# [1111]	validation_0-mae:19.97340
# [1112]	validation_0-mae:19.97335
# [1113]	validation_0-mae:19.97098
# [1114]	validation_0-mae:19.97092
# [1115]	validation_0-mae:19.97133
# [1116]	validation_0-mae:19.97013
# [1117]	validation_0-mae:19.96927
# [1118]	validation_0-mae:19.96998
# [1119]	validation_0-mae:19.97058
# [1120]	validation_0-mae:19.97109
# [1121]	validation_0-mae:19.97050
# [1122]	validation_0-mae:19.97072
# [1123]	validation_0-mae:19.96944
# [1124]	validation_0-mae:19.97056
# [1125]	validation_0-mae:19.97084
# [1126]	validation_0-mae:19.97043
# [1127]	validation_0-mae:19.96932
# [1128]	validation_0-mae:19.96841
# [1129]	validation_0-mae:19.96825
# [1130]	validation_0-mae:19.96798
# [1131]	validation_0-mae:19.96645
# [1132]	validation_0-mae:19.96719
# [1133]	validation_0-mae:19.96742
# [1134]	validation_0-mae:19.96645
# [1135]	validation_0-mae:19.96743
# [1136]	validation_0-mae:19.96687
# [1137]	validation_0-mae:19.96613
# [1138]	validation_0-mae:19.96643
# [1139]	validation_0-mae:19.96534
# [1140]	validation_0-mae:19.96498
# [1141]	validation_0-mae:19.96473
# [1142]	validation_0-mae:19.96525
# [1143]	validation_0-mae:19.96597
# [1144]	validation_0-mae:19.96528
# [1145]	validation_0-mae:19.96564
# [1146]	validation_0-mae:19.96607
# [1147]	validation_0-mae:19.96663
# [1148]	validation_0-mae:19.96509
# [1149]	validation_0-mae:19.96488
# [1150]	validation_0-mae:19.96417
# [1151]	validation_0-mae:19.96376
# [1152]	validation_0-mae:19.96379
# [1153]	validation_0-mae:19.96307
# [1154]	validation_0-mae:19.96334
# [1155]	validation_0-mae:19.96139
# [1156]	validation_0-mae:19.96220
# [1157]	validation_0-mae:19.96231
# [1158]	validation_0-mae:19.96218
# [1159]	validation_0-mae:19.96033
# [1160]	validation_0-mae:19.96005
# [1161]	validation_0-mae:19.96052
# [1162]	validation_0-mae:19.96024
# [1163]	validation_0-mae:19.95989
# [1164]	validation_0-mae:19.95988
# [1165]	validation_0-mae:19.95990
# [1166]	validation_0-mae:19.95935
# [1167]	validation_0-mae:19.95827
# [1168]	validation_0-mae:19.95924
# [1169]	validation_0-mae:19.95910
# [1170]	validation_0-mae:19.95759
# [1171]	validation_0-mae:19.95692
# [1172]	validation_0-mae:19.95819
# [1173]	validation_0-mae:19.95903
# [1174]	validation_0-mae:19.96022
# [1175]	validation_0-mae:19.96110
# [1176]	validation_0-mae:19.95965
# [1177]	validation_0-mae:19.95933
# [1178]	validation_0-mae:19.95979
# [1179]	validation_0-mae:19.95848
# [1180]	validation_0-mae:19.95708
# [1181]	validation_0-mae:19.95661
# [1182]	validation_0-mae:19.95799
# [1183]	validation_0-mae:19.95857
# [1184]	validation_0-mae:19.95859
# [1185]	validation_0-mae:19.95655
# [1186]	validation_0-mae:19.95626
# [1187]	validation_0-mae:19.95490
# [1188]	validation_0-mae:19.95469
# [1189]	validation_0-mae:19.95472
# [1190]	validation_0-mae:19.95483
# [1191]	validation_0-mae:19.95478
# [1192]	validation_0-mae:19.95558
# [1193]	validation_0-mae:19.95506
# [1194]	validation_0-mae:19.95476
# [1195]	validation_0-mae:19.95421
# [1196]	validation_0-mae:19.95577
# [1197]	validation_0-mae:19.95553
# [1198]	validation_0-mae:19.95508
# [1199]	validation_0-mae:19.95607
# [1200]	validation_0-mae:19.95491
# [1201]	validation_0-mae:19.95294
# [1202]	validation_0-mae:19.95297
# [1203]	validation_0-mae:19.95120
# [1204]	validation_0-mae:19.95072
# [1205]	validation_0-mae:19.95012
# [1206]	validation_0-mae:19.94979
# [1207]	validation_0-mae:19.94965
# [1208]	validation_0-mae:19.94950
# [1209]	validation_0-mae:19.95034
# [1210]	validation_0-mae:19.95046
# [1211]	validation_0-mae:19.94976
# [1212]	validation_0-mae:19.95002
# [1213]	validation_0-mae:19.94947
# [1214]	validation_0-mae:19.94875
# [1215]	validation_0-mae:19.94918
# [1216]	validation_0-mae:19.94731
# [1217]	validation_0-mae:19.94769
# [1218]	validation_0-mae:19.94855
# [1219]	validation_0-mae:19.94884
# [1220]	validation_0-mae:19.94857
# [1221]	validation_0-mae:19.94905
# [1222]	validation_0-mae:19.94869
# [1223]	validation_0-mae:19.94852
# [1224]	validation_0-mae:19.94759
# [1225]	validation_0-mae:19.94761
# [1226]	validation_0-mae:19.94937
# [1227]	validation_0-mae:19.94893
# [1228]	validation_0-mae:19.94739
# [1229]	validation_0-mae:19.94670
# [1230]	validation_0-mae:19.94640
# [1231]	validation_0-mae:19.94529
# [1232]	validation_0-mae:19.94533
# [1233]	validation_0-mae:19.94497
# [1234]	validation_0-mae:19.94407
# [1235]	validation_0-mae:19.94458
# [1236]	validation_0-mae:19.94361
# [1237]	validation_0-mae:19.94256
# [1238]	validation_0-mae:19.94200
# [1239]	validation_0-mae:19.94006
# [1240]	validation_0-mae:19.94019
# [1241]	validation_0-mae:19.93939
# [1242]	validation_0-mae:19.93910
# [1243]	validation_0-mae:19.93934
# [1244]	validation_0-mae:19.93802
# [1245]	validation_0-mae:19.93831
# [1246]	validation_0-mae:19.93779
# [1247]	validation_0-mae:19.93952
# [1248]	validation_0-mae:19.93806
# [1249]	validation_0-mae:19.93726
# [1250]	validation_0-mae:19.93569
# [1251]	validation_0-mae:19.93597
# [1252]	validation_0-mae:19.93379
# [1253]	validation_0-mae:19.93364
# [1254]	validation_0-mae:19.93391
# [1255]	validation_0-mae:19.93335
# [1256]	validation_0-mae:19.93307
# [1257]	validation_0-mae:19.93193
# [1258]	validation_0-mae:19.93196
# [1259]	validation_0-mae:19.93214
# [1260]	validation_0-mae:19.93099
# [1261]	validation_0-mae:19.92982
# [1262]	validation_0-mae:19.92936
# [1263]	validation_0-mae:19.92960
# [1264]	validation_0-mae:19.92947
# [1265]	validation_0-mae:19.92947
# [1266]	validation_0-mae:19.93072
# [1267]	validation_0-mae:19.92905
# [1268]	validation_0-mae:19.92868
# [1269]	validation_0-mae:19.92793
# [1270]	validation_0-mae:19.92817
# [1271]	validation_0-mae:19.92853
# [1272]	validation_0-mae:19.92792
# [1273]	validation_0-mae:19.92775
# [1274]	validation_0-mae:19.92634
# [1275]	validation_0-mae:19.92581
# [1276]	validation_0-mae:19.92457
# [1277]	validation_0-mae:19.92409
# [1278]	validation_0-mae:19.92355
# [1279]	validation_0-mae:19.92356
# [1280]	validation_0-mae:19.92438
# [1281]	validation_0-mae:19.92422
# [1282]	validation_0-mae:19.92355
# [1283]	validation_0-mae:19.92329
# [1284]	validation_0-mae:19.92390
# [1285]	validation_0-mae:19.92382
# [1286]	validation_0-mae:19.92332
# [1287]	validation_0-mae:19.92322
# [1288]	validation_0-mae:19.92414
# [1289]	validation_0-mae:19.92418
# [1290]	validation_0-mae:19.92423
# [1291]	validation_0-mae:19.92302
# [1292]	validation_0-mae:19.92197
# [1293]	validation_0-mae:19.92282
# [1294]	validation_0-mae:19.92157
# [1295]	validation_0-mae:19.92225
# [1296]	validation_0-mae:19.92019
# [1297]	validation_0-mae:19.92035
# [1298]	validation_0-mae:19.91971
# [1299]	validation_0-mae:19.91944
# [1300]	validation_0-mae:19.91855
# [1301]	validation_0-mae:19.91892
# [1302]	validation_0-mae:19.91957
# [1303]	validation_0-mae:19.91913
# [1304]	validation_0-mae:19.92037
# [1305]	validation_0-mae:19.91915
# [1306]	validation_0-mae:19.91973
# [1307]	validation_0-mae:19.91943
# [1308]	validation_0-mae:19.91979
# [1309]	validation_0-mae:19.91914
# [1310]	validation_0-mae:19.91906
# [1311]	validation_0-mae:19.91958
# [1312]	validation_0-mae:19.91955
# [1313]	validation_0-mae:19.91873
# [1314]	validation_0-mae:19.91872
# [1315]	validation_0-mae:19.91847
# [1316]	validation_0-mae:19.91778
# [1317]	validation_0-mae:19.91765
# [1318]	validation_0-mae:19.91792
# [1319]	validation_0-mae:19.91817
# [1320]	validation_0-mae:19.91815
# [1321]	validation_0-mae:19.91649
# [1322]	validation_0-mae:19.91559
# [1323]	validation_0-mae:19.91498
# [1324]	validation_0-mae:19.91507
# ...
# [2850]	validation_0-mae:19.74554
# [2851]	validation_0-mae:19.74535
# [2852]	validation_0-mae:19.74525
# [2853]	validation_0-mae:19.74515
# [2854]	validation_0-mae:19.74519
# [2855]	validation_0-mae:19.74512
# [2856]	validation_0-mae:19.74514
# [2857]	validation_0-mae:19.74533
# [2858]	validation_0-mae:19.74547
# [2859]	validation_0-mae:19.74566
# [2860]	validation_0-mae:19.74576
# [2861]	validation_0-mae:19.74565
# [2862]	validation_0-mae:19.74541
# [2863]	validation_0-mae:19.74535
# [2864]	validation_0-mae:19.74533
# [2865]	validation_0-mae:19.74526
# [2866]	validation_0-mae:19.74500
# [2867]	validation_0-mae:19.74496
# [2868]	validation_0-mae:19.74484
# [2869]	validation_0-mae:19.74483
# [2870]	validation_0-mae:19.74491
# [2871]	validation_0-mae:19.74500
# [2872]	validation_0-mae:19.74468
# [2873]	validation_0-mae:19.74447
# [2874]	validation_0-mae:19.74429
# [2875]	validation_0-mae:19.74417
# [2876]	validation_0-mae:19.74404
# [2877]	validation_0-mae:19.74395
# [2878]	validation_0-mae:19.74397
# [2879]	validation_0-mae:19.74377
# [2880]	validation_0-mae:19.74388
# [2881]	validation_0-mae:19.74379
# [2882]	validation_0-mae:19.74389
# [2883]	validation_0-mae:19.74376
# [2884]	validation_0-mae:19.74365
# [2885]	validation_0-mae:19.74372
# [2886]	validation_0-mae:19.74371
# [2887]	validation_0-mae:19.74356
# [2888]	validation_0-mae:19.74346
# [2889]	validation_0-mae:19.74346
# [2890]	validation_0-mae:19.74346
# [2891]	validation_0-mae:19.74345
# [2892]	validation_0-mae:19.74327
# [2893]	validation_0-mae:19.74328
# [2894]	validation_0-mae:19.74338
# [2895]	validation_0-mae:19.74322
# [2896]	validation_0-mae:19.74335
# [2897]	validation_0-mae:19.74347
# [2898]	validation_0-mae:19.74345
# [2899]	validation_0-mae:19.74355
# [2900]	validation_0-mae:19.74340
# [2901]	validation_0-mae:19.74331
# [2902]	validation_0-mae:19.74352
# [2903]	validation_0-mae:19.74353
# [2904]	validation_0-mae:19.74360
# [2905]	validation_0-mae:19.74344
# [2906]	validation_0-mae:19.74347
# [2907]	validation_0-mae:19.74324
# [2908]	validation_0-mae:19.74311
# [2909]	validation_0-mae:19.74306
# [2910]	validation_0-mae:19.74280
# [2911]	validation_0-mae:19.74270
# [2912]	validation_0-mae:19.74269
# [2913]	validation_0-mae:19.74256
# [2914]	validation_0-mae:19.74241
# [2915]	validation_0-mae:19.74229
# [2916]	validation_0-mae:19.74239
# [2917]	validation_0-mae:19.74247
# [2918]	validation_0-mae:19.74250
# [2919]	validation_0-mae:19.74251
# [2920]	validation_0-mae:19.74264
# [2921]	validation_0-mae:19.74263
# [2922]	validation_0-mae:19.74266
# [2923]	validation_0-mae:19.74255
# [2924]	validation_0-mae:19.74257
# [2925]	validation_0-mae:19.74262
# [2926]	validation_0-mae:19.74272
# [2927]	validation_0-mae:19.74283
# [2928]	validation_0-mae:19.74275
# [2929]	validation_0-mae:19.74271
# [2930]	validation_0-mae:19.74269
# [2931]	validation_0-mae:19.74262
# [2932]	validation_0-mae:19.74259
# [2933]	validation_0-mae:19.74252
# [2934]	validation_0-mae:19.74254
# [2935]	validation_0-mae:19.74273
# [2936]	validation_0-mae:19.74260
# [2937]	validation_0-mae:19.74257
# [2938]	validation_0-mae:19.74255
# [2939]	validation_0-mae:19.74241
# [2940]	validation_0-mae:19.74248
# [2941]	validation_0-mae:19.74247
# [2942]	validation_0-mae:19.74259
# [2943]	validation_0-mae:19.74254
# [2944]	validation_0-mae:19.74266
# [2945]	validation_0-mae:19.74257
# [2946]	validation_0-mae:19.74249
# [2947]	validation_0-mae:19.74235
# [2948]	validation_0-mae:19.74235
# [2949]	validation_0-mae:19.74242
# [2950]	validation_0-mae:19.74239
# [2951]	validation_0-mae:19.74228
# [2952]	validation_0-mae:19.74233
# [2953]	validation_0-mae:19.74234
# [2954]	validation_0-mae:19.74233
# [2955]	validation_0-mae:19.74214
# [2956]	validation_0-mae:19.74213
# [2957]	validation_0-mae:19.74231
# [2958]	validation_0-mae:19.74225
# [2959]	validation_0-mae:19.74219
# [2960]	validation_0-mae:19.74205
# [2961]	validation_0-mae:19.74211
# [2962]	validation_0-mae:19.74197
# [2963]	validation_0-mae:19.74198
# [2964]	validation_0-mae:19.74186
# [2965]	validation_0-mae:19.74199
# [2966]	validation_0-mae:19.74201
# [2967]	validation_0-mae:19.74211
# [2968]	validation_0-mae:19.74222
# [2969]	validation_0-mae:19.74237
# [2970]	validation_0-mae:19.74243
# [2971]	validation_0-mae:19.74233
# [2972]	validation_0-mae:19.74239
# [2973]	validation_0-mae:19.74252
# [2974]	validation_0-mae:19.74230
# [2975]	validation_0-mae:19.74222
# [2976]	validation_0-mae:19.74210
# [2977]	validation_0-mae:19.74206
# [2978]	validation_0-mae:19.74208
# [2979]	validation_0-mae:19.74191
# [2980]	validation_0-mae:19.74182
# [2981]	validation_0-mae:19.74174
# [2982]	validation_0-mae:19.74181
# [2983]	validation_0-mae:19.74182
# [2984]	validation_0-mae:19.74165
# [2985]	validation_0-mae:19.74173
# [2986]	validation_0-mae:19.74164
# [2987]	validation_0-mae:19.74164
# [2988]	validation_0-mae:19.74160
# [2989]	validation_0-mae:19.74137
# [2990]	validation_0-mae:19.74156
# [2991]	validation_0-mae:19.74187
# [2992]	validation_0-mae:19.74188
# [2993]	validation_0-mae:19.74211
# [2994]	validation_0-mae:19.74199
# [2995]	validation_0-mae:19.74193
# [2996]	validation_0-mae:19.74205
# [2997]	validation_0-mae:19.74195
# [2998]	validation_0-mae:19.74182
# [2999]	validation_0-mae:19.74176
# [3000]	validation_0-mae:19.74163
# [3001]	validation_0-mae:19.74176
# [3002]	validation_0-mae:19.74154
# [3003]	validation_0-mae:19.74147
# [3004]	validation_0-mae:19.74139
# [3005]	validation_0-mae:19.74164
# [3006]	validation_0-mae:19.74131
# [3007]	validation_0-mae:19.74124
# [3008]	validation_0-mae:19.74124
# [3009]	validation_0-mae:19.74100
# [3010]	validation_0-mae:19.74108
# [3011]	validation_0-mae:19.74110
# [3012]	validation_0-mae:19.74098
# [3013]	validation_0-mae:19.74086
# [3014]	validation_0-mae:19.74102
# [3015]	validation_0-mae:19.74113
# [3016]	validation_0-mae:19.74106
# [3017]	validation_0-mae:19.74109
# [3018]	validation_0-mae:19.74107
# [3019]	validation_0-mae:19.74095
# [3020]	validation_0-mae:19.74089
# [3021]	validation_0-mae:19.74097
# [3022]	validation_0-mae:19.74088
# [3023]	validation_0-mae:19.74087
# [3024]	validation_0-mae:19.74064
# [3025]	validation_0-mae:19.74069
# [3026]	validation_0-mae:19.74070
# [3027]	validation_0-mae:19.74080
# [3028]	validation_0-mae:19.74078
# [3029]	validation_0-mae:19.74073
# [3030]	validation_0-mae:19.74047
# [3031]	validation_0-mae:19.74058
# [3032]	validation_0-mae:19.74068
# [3033]	validation_0-mae:19.74064
# [3034]	validation_0-mae:19.74069
# [3035]	validation_0-mae:19.74060
# [3036]	validation_0-mae:19.74060
# [3037]	validation_0-mae:19.74052
# [3038]	validation_0-mae:19.74055
# [3039]	validation_0-mae:19.74065
# [3040]	validation_0-mae:19.74051
# [3041]	validation_0-mae:19.74048
# [3042]	validation_0-mae:19.74066
# [3043]	validation_0-mae:19.74055
# [3044]	validation_0-mae:19.74018
# [3045]	validation_0-mae:19.74006
# [3046]	validation_0-mae:19.74002
# [3047]	validation_0-mae:19.74015
# [3048]	validation_0-mae:19.74005
# [3049]	validation_0-mae:19.73975
# [3050]	validation_0-mae:19.73964
# [3051]	validation_0-mae:19.73962
# [3052]	validation_0-mae:19.73973
# [3053]	validation_0-mae:19.73972
# [3054]	validation_0-mae:19.73958
# [3055]	validation_0-mae:19.73960
# [3056]	validation_0-mae:19.73946
# [3057]	validation_0-mae:19.73947
# [3058]	validation_0-mae:19.73953
# [3059]	validation_0-mae:19.73937
# [3060]	validation_0-mae:19.73928
# [3061]	validation_0-mae:19.73920
# [3062]	validation_0-mae:19.73923
# [3063]	validation_0-mae:19.73905
# [3064]	validation_0-mae:19.73926
# [3065]	validation_0-mae:19.73924
# [3066]	validation_0-mae:19.73907
# [3067]	validation_0-mae:19.73916
# [3068]	validation_0-mae:19.73904
# [3069]	validation_0-mae:19.73887
# [3070]	validation_0-mae:19.73874
# [3071]	validation_0-mae:19.73876
# [3072]	validation_0-mae:19.73867
# [3073]	validation_0-mae:19.73866
# [3074]	validation_0-mae:19.73863
# [3075]	validation_0-mae:19.73875
# [3076]	validation_0-mae:19.73859
# [3077]	validation_0-mae:19.73881
# [3078]	validation_0-mae:19.73868
# [3079]	validation_0-mae:19.73857
# [3080]	validation_0-mae:19.73865
# [3081]	validation_0-mae:19.73873
# [3082]	validation_0-mae:19.73863
# [3083]	validation_0-mae:19.73850
# [3084]	validation_0-mae:19.73828
# [3085]	validation_0-mae:19.73837
# [3086]	validation_0-mae:19.73841
# [3087]	validation_0-mae:19.73839
# [3088]	validation_0-mae:19.73833
# [3089]	validation_0-mae:19.73833
# [3090]	validation_0-mae:19.73834
# [3091]	validation_0-mae:19.73808
# [3092]	validation_0-mae:19.73806
# [3093]	validation_0-mae:19.73808
# [3094]	validation_0-mae:19.73791
# [3095]	validation_0-mae:19.73769
# [3096]	validation_0-mae:19.73768
# [3097]	validation_0-mae:19.73784
# [3098]	validation_0-mae:19.73775
# [3099]	validation_0-mae:19.73765
# [3100]	validation_0-mae:19.73778
# [3101]	validation_0-mae:19.73782
# [3102]	validation_0-mae:19.73790
# [3103]	validation_0-mae:19.73783
# [3104]	validation_0-mae:19.73772
# [3105]	validation_0-mae:19.73781
# [3106]	validation_0-mae:19.73765
# [3107]	validation_0-mae:19.73754
# [3108]	validation_0-mae:19.73737
# [3109]	validation_0-mae:19.73733
# [3110]	validation_0-mae:19.73713
# [3111]	validation_0-mae:19.73698
# [3112]	validation_0-mae:19.73715
# [3113]	validation_0-mae:19.73701
# [3114]	validation_0-mae:19.73700
# [3115]	validation_0-mae:19.73693
# [3116]	validation_0-mae:19.73710
# [3117]	validation_0-mae:19.73719
# [3118]	validation_0-mae:19.73723
# [3119]	validation_0-mae:19.73719
# [3120]	validation_0-mae:19.73702
# [3121]	validation_0-mae:19.73675
# [3122]	validation_0-mae:19.73680
# [3123]	validation_0-mae:19.73683
# [3124]	validation_0-mae:19.73684
# [3125]	validation_0-mae:19.73677
# [3126]	validation_0-mae:19.73666
# [3127]	validation_0-mae:19.73670
# [3128]	validation_0-mae:19.73643
# [3129]	validation_0-mae:19.73670
# [3130]	validation_0-mae:19.73651
# [3131]	validation_0-mae:19.73645
# [3132]	validation_0-mae:19.73646
# [3133]	validation_0-mae:19.73647
# [3134]	validation_0-mae:19.73646
# [3135]	validation_0-mae:19.73642
# [3136]	validation_0-mae:19.73640
# [3137]	validation_0-mae:19.73637
# [3138]	validation_0-mae:19.73640
# [3139]	validation_0-mae:19.73626
# [3140]	validation_0-mae:19.73613
# [3141]	validation_0-mae:19.73613
# [3142]	validation_0-mae:19.73613
# [3143]	validation_0-mae:19.73610
# [3144]	validation_0-mae:19.73606
# [3145]	validation_0-mae:19.73593
# [3146]	validation_0-mae:19.73603
# [3147]	validation_0-mae:19.73600
# [3148]	validation_0-mae:19.73590
# [3149]	validation_0-mae:19.73577
# [3150]	validation_0-mae:19.73569
# [3151]	validation_0-mae:19.73562
# [3152]	validation_0-mae:19.73564
# [3153]	validation_0-mae:19.73567
# [3154]	validation_0-mae:19.73576
# [3155]	validation_0-mae:19.73581
# [3156]	validation_0-mae:19.73567
# [3157]	validation_0-mae:19.73582
# [3158]	validation_0-mae:19.73576
# [3159]	validation_0-mae:19.73571
# [3160]	validation_0-mae:19.73583
# [3161]	validation_0-mae:19.73582
# [3162]	validation_0-mae:19.73577
# [3163]	validation_0-mae:19.73567
# [3164]	validation_0-mae:19.73568
# [3165]	validation_0-mae:19.73568
# [3166]	validation_0-mae:19.73577
# [3167]	validation_0-mae:19.73573
# [3168]	validation_0-mae:19.73551
# [3169]	validation_0-mae:19.73541
# [3170]	validation_0-mae:19.73547
# [3171]	validation_0-mae:19.73537
# [3172]	validation_0-mae:19.73546
# [3173]	validation_0-mae:19.73541
# [3174]	validation_0-mae:19.73544
# [3175]	validation_0-mae:19.73554
# [3176]	validation_0-mae:19.73550
# [3177]	validation_0-mae:19.73556
# [3178]	validation_0-mae:19.73535
# [3179]	validation_0-mae:19.73522
# [3180]	validation_0-mae:19.73522
# [3181]	validation_0-mae:19.73509
# [3182]	validation_0-mae:19.73498
# [3183]	validation_0-mae:19.73497
# [3184]	validation_0-mae:19.73493
# [3185]	validation_0-mae:19.73477
# [3186]	validation_0-mae:19.73477
# [3187]	validation_0-mae:19.73472
# [3188]	validation_0-mae:19.73458
# [3189]	validation_0-mae:19.73457
# [3190]	validation_0-mae:19.73450
# [3191]	validation_0-mae:19.73453
# [3192]	validation_0-mae:19.73457
# [3193]	validation_0-mae:19.73447
# [3194]	validation_0-mae:19.73453
# [3195]	validation_0-mae:19.73453
# [3196]	validation_0-mae:19.73446
# [3197]	validation_0-mae:19.73452
# [3198]	validation_0-mae:19.73465
# [3199]	validation_0-mae:19.73470
# [3200]	validation_0-mae:19.73467
# [3201]	validation_0-mae:19.73480
# [3202]	validation_0-mae:19.73474
# [3203]	validation_0-mae:19.73482
# [3204]	validation_0-mae:19.73475
# [3205]	validation_0-mae:19.73466
# [3206]	validation_0-mae:19.73457
# [3207]	validation_0-mae:19.73445
# [3208]	validation_0-mae:19.73448
# [3209]	validation_0-mae:19.73438
# [3210]	validation_0-mae:19.73439
# [3211]	validation_0-mae:19.73422
# [3212]	validation_0-mae:19.73410
# [3213]	validation_0-mae:19.73401
# [3214]	validation_0-mae:19.73397
# [3215]	validation_0-mae:19.73392
# [3216]	validation_0-mae:19.73402
# [3217]	validation_0-mae:19.73401
# [3218]	validation_0-mae:19.73407
# [3219]	validation_0-mae:19.73404
# [3220]	validation_0-mae:19.73394
# [3221]	validation_0-mae:19.73391
# [3222]	validation_0-mae:19.73387
# [3223]	validation_0-mae:19.73388
# [3224]	validation_0-mae:19.73398
# [3225]	validation_0-mae:19.73390
# [3226]	validation_0-mae:19.73394
# [3227]	validation_0-mae:19.73392
# [3228]	validation_0-mae:19.73385
# [3229]	validation_0-mae:19.73397
# [3230]	validation_0-mae:19.73391
# [3231]	validation_0-mae:19.73381
# [3232]	validation_0-mae:19.73394
# [3233]	validation_0-mae:19.73379
# [3234]	validation_0-mae:19.73370
# [3235]	validation_0-mae:19.73379
# [3236]	validation_0-mae:19.73368
# [3237]	validation_0-mae:19.73365
# [3238]	validation_0-mae:19.73369
# [3239]	validation_0-mae:19.73383
# [3240]	validation_0-mae:19.73377
# [3241]	validation_0-mae:19.73385
# [3242]	validation_0-mae:19.73370
# [3243]	validation_0-mae:19.73361
# [3244]	validation_0-mae:19.73368
# [3245]	validation_0-mae:19.73351
# [3246]	validation_0-mae:19.73362
# [3247]	validation_0-mae:19.73356
# [3248]	validation_0-mae:19.73353
# [3249]	validation_0-mae:19.73353
# [3250]	validation_0-mae:19.73345
# [3251]	validation_0-mae:19.73333
# [3252]	validation_0-mae:19.73317
# [3253]	validation_0-mae:19.73320
# [3254]	validation_0-mae:19.73320
# [3255]	validation_0-mae:19.73309
# [3256]	validation_0-mae:19.73322
# [3257]	validation_0-mae:19.73323
# [3258]	validation_0-mae:19.73317
# [3259]	validation_0-mae:19.73311
# [3260]	validation_0-mae:19.73310
# [3261]	validation_0-mae:19.73316
# [3262]	validation_0-mae:19.73322
# [3263]	validation_0-mae:19.73327
# [3264]	validation_0-mae:19.73315
# [3265]	validation_0-mae:19.73298
# [3266]	validation_0-mae:19.73281
# [3267]	validation_0-mae:19.73269
# [3268]	validation_0-mae:19.73260
# [3269]	validation_0-mae:19.73255
# [3270]	validation_0-mae:19.73256
# [3271]	validation_0-mae:19.73254
# [3272]	validation_0-mae:19.73254
# [3273]	validation_0-mae:19.73258
# [3274]	validation_0-mae:19.73250
# [3275]	validation_0-mae:19.73249
# [3276]	validation_0-mae:19.73255
# [3277]	validation_0-mae:19.73252
# [3278]	validation_0-mae:19.73252
# [3279]	validation_0-mae:19.73255
# [3280]	validation_0-mae:19.73247
# [3281]	validation_0-mae:19.73263
# [3282]	validation_0-mae:19.73271
# [3283]	validation_0-mae:19.73266
# [3284]	validation_0-mae:19.73267
# [3285]	validation_0-mae:19.73265
# [3286]	validation_0-mae:19.73271
# [3287]	validation_0-mae:19.73263
# [3288]	validation_0-mae:19.73269
# [3289]	validation_0-mae:19.73273
# [3290]	validation_0-mae:19.73269
# [3291]	validation_0-mae:19.73263
# [3292]	validation_0-mae:19.73279
# [3293]	validation_0-mae:19.73278
# [3294]	validation_0-mae:19.73273
# [3295]	validation_0-mae:19.73284
# [3296]	validation_0-mae:19.73299
# [3297]	validation_0-mae:19.73296
# [3298]	validation_0-mae:19.73300
# [3299]	validation_0-mae:19.73292
# [3300]	validation_0-mae:19.73307
# [3301]	validation_0-mae:19.73309
# [3302]	validation_0-mae:19.73298
# [3303]	validation_0-mae:19.73289
# [3304]	validation_0-mae:19.73299
# [3305]	validation_0-mae:19.73309
# [3306]	validation_0-mae:19.73307
# [3307]	validation_0-mae:19.73305
# [3308]	validation_0-mae:19.73304
# [3309]	validation_0-mae:19.73308
# [3310]	validation_0-mae:19.73300
# [3311]	validation_0-mae:19.73300
# [3312]	validation_0-mae:19.73299
# [3313]	validation_0-mae:19.73295
# [3314]	validation_0-mae:19.73298
# [3315]	validation_0-mae:19.73293
# [3316]	validation_0-mae:19.73301
# [3317]	validation_0-mae:19.73296
# [3318]	validation_0-mae:19.73297
# [3319]	validation_0-mae:19.73295
# [3320]	validation_0-mae:19.73288
# [3321]	validation_0-mae:19.73289
# [3322]	validation_0-mae:19.73288
# [3323]	validation_0-mae:19.73291
# [3324]	validation_0-mae:19.73292
# [3325]	validation_0-mae:19.73284
# [3326]	validation_0-mae:19.73270
# [3327]	validation_0-mae:19.73261
# [3328]	validation_0-mae:19.73268
# [3329]	validation_0-mae:19.73262
# [3330]	validation_0-mae:19.73270
# xgb_model 已保存到 xgb_model.pkl
# Valid絕對誤差總和: 102490.46914701877
# XGBoost 預測結果已儲存至 XGBoost_Predictions_xgb.csv
